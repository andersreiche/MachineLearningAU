# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.cluster import KMeans
import pandas as pd

dataset = '/home/anders/ml/BDA2018_aarhus/data/kmeans/2015-05-26_17-11-46.csv'

df = pd.read_csv(dataset, index_col=0)
df
# Out:
#                          loggingSample  locationTimestamp_since1970  \
# loggingTime
# 2015-05-26 17:11:47.040              1                 1.432653e+09
# 2015-05-26 17:11:47.121              2                 1.432653e+09
# 2015-05-26 17:11:47.126              3                 1.432653e+09
# 2015-05-26 17:11:47.131              4                 1.432653e+09
# 2015-05-26 17:11:47.134              5                 1.432653e+09
# 2015-05-26 17:11:47.137              6                 1.432653e+09
# 2015-05-26 17:11:47.140              7                 1.432653e+09
# 2015-05-26 17:11:47.209              8                 1.432653e+09
# 2015-05-26 17:11:47.213              9                 1.432653e+09
# 2015-05-26 17:11:47.216             10                 1.432653e+09
# 2015-05-26 17:11:47.221             11                 1.432653e+09
# 2015-05-26 17:11:47.225             12                 1.432653e+09
# 2015-05-26 17:11:47.249             13                 1.432653e+09
# ...

# %%
X = df[["accelerometerAccelerationX", "accelerometerAccelerationY", "accelerometerAccelerationZ"]]

model = KMeans(n_clusters=6).fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = model.cluster_centers_

# %%
for cluster in clusters:
    print(linalg.norm(cluster))
# Out:
# 1.0391358316504105
# 1.048892374593724
# 1.0509042318687472
# 1.068378878353028
# 1.0394619464086452
# 1.0707291974715913

# %%
mode = model.predict(X)
df["cluster"] = mode

# %%
df
# Out:
#                          loggingSample  locationTimestamp_since1970  \
# loggingTime
# 2015-05-26 17:11:47.040              1                 1.432653e+09
# 2015-05-26 17:11:47.121              2                 1.432653e+09
# 2015-05-26 17:11:47.126              3                 1.432653e+09
# 2015-05-26 17:11:47.131              4                 1.432653e+09
# 2015-05-26 17:11:47.134              5                 1.432653e+09
# 2015-05-26 17:11:47.137              6                 1.432653e+09
# 2015-05-26 17:11:47.140              7                 1.432653e+09
# 2015-05-26 17:11:47.209              8                 1.432653e+09
# 2015-05-26 17:11:47.213              9                 1.432653e+09
# 2015-05-26 17:11:47.216             10                 1.432653e+09
# 2015-05-26 17:11:47.221             11                 1.432653e+09
# 2015-05-26 17:11:47.225             12                 1.432653e+09
# 2015-05-26 17:11:47.249             13                 1.432653e+09
# ...

# %%
cluster_speed = df[["locationSpeed", "cluster"]]
cluster_speed
# Out:
#                          locationSpeed  cluster
# loggingTime
# 2015-05-26 17:11:47.040      -1.000000        4
# 2015-05-26 17:11:47.121      -1.000000        4
# 2015-05-26 17:11:47.126      -1.000000        4
# 2015-05-26 17:11:47.131      -1.000000        4
# 2015-05-26 17:11:47.134      -1.000000        4
# 2015-05-26 17:11:47.137      -1.000000        4
# 2015-05-26 17:11:47.140      -1.000000        4
# 2015-05-26 17:11:47.209      -1.000000        4
# 2015-05-26 17:11:47.213      -1.000000        4
# 2015-05-26 17:11:47.216      -1.000000        4
# 2015-05-26 17:11:47.221      -1.000000        4
# 2015-05-26 17:11:47.225      -1.000000        4
# 2015-05-26 17:11:47.249      -1.000000        4
# 2015-05-26 17:11:47.253      -1.000000        4
# 2015-05-26 17:11:47.260      -1.000000        4
# 2015-05-26 17:11:47.265      -1.000000        4
# 2015-05-26 17:11:47.268      -1.000000        4
# 2015-05-26 17:11:47.273      -1.000000        4
# ...

# %%
cluster_speed["locationSpeed"].plot()

# %%
for i in range(6):
    cluster_speed[f'cluster{i}'] = cluster_speed['locationSpeed'][cluster_speed['cluster']==i]
    
cluster_speed
# Out:
# /home/anders/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          locationSpeed  cluster  cluster0  cluster1  cluster2  \
# loggingTime
# 2015-05-26 17:11:47.040      -1.000000        4       NaN       NaN       NaN
# 2015-05-26 17:11:47.121      -1.000000        4       NaN       NaN       NaN
# 2015-05-26 17:11:47.126      -1.000000        4       NaN       NaN       NaN
# 2015-05-26 17:11:47.131      -1.000000        4       NaN       NaN       NaN
# 2015-05-26 17:11:47.134      -1.000000        4       NaN       NaN       NaN
# 2015-05-26 17:11:47.137      -1.000000        4       NaN       NaN       NaN
# ...

# %%
cluster_speed.plot(y=['cluster0','cluster1','cluster2','cluster3','cluster4','cluster5'], figsize=(20,10))
plot()
# Out:
# []
